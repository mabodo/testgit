# %% [markdown]
# <a href="https://colab.research.google.com/github/mabodo/testgit/blob/master/Colab_Basic_Tempate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Imports and Authentication
# %pylab inline
import numpy as np
import seaborn as sns
import scipy.stats as st
import pandas as pd

from google.colab import auth
from google.cloud import bigquery

auth.authenticate_user()
print('Authenticated')

GOOGLE_CLOUD_PROJECT = 'badi-datascience'
client = bigquery.Client(project=GOOGLE_CLOUD_PROJECT)

#dat table shows df cooler, maximum 20 columns
# %load_ext google.colab.data_table
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Authenticated
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %% [markdown]
# # Title for the notebook here
# **Author(s):**
#
# **Context:**
#
# **Outcome:**

# %% [markdown]
# ## Section 1

# %%
df = client.query('''
SELECT booking_id, seeker_id, room_id, booking_proposal_created_at, booking_created_at, booking_proposal_id
FROM `badi-datascience.layer_1.bookings` 
ORDER BY booking_created_at DESC
LIMIT 200
''').to_dataframe()

# %%
df
# Out:
#      booking_id  seeker_id  ...        booking_created_at booking_proposal_id
# 0         19519    2285928  ... 2020-02-05 00:27:07+00:00              123608
# 1         19516     909282  ... 2020-02-04 23:07:20+00:00              122123
# 2         19515    1926287  ... 2020-02-04 23:05:04+00:00              123401
# 3         19513    2262342  ... 2020-02-04 22:42:48+00:00              123506
# 4         19512    2265871  ... 2020-02-04 22:33:12+00:00              123501
# ..          ...        ...  ...                       ...                 ...
# 195       18970    2267052  ... 2020-01-27 21:54:52+00:00              107839
# 196       18969    2230610  ... 2020-01-27 21:41:06+00:00              111700
# 197       18967    2223622  ... 2020-01-27 21:30:05+00:00              111715
# 198       18966    2107804  ... 2020-01-27 21:11:54+00:00              111427
# 199       18965    2041410  ... 2020-01-27 21:11:06+00:00              109402
#
# [200 rows x 6 columns]

# %%
plt.figure(figsize=(10,5))
plt.plot(df['booking_created_at'], df['booking_proposal_id'], '.')
plt.ylabel('proposal id')
plt.xlabel('created at')
sns.despine()

# %% [markdown]
# # Share your notebook if fancy

# %%
repo_name = ''
organization = ''
username = ''
password = ''
file_name = ''

# %%
#@title Copy in your colab ⬇️
from IPython.core.display import HTML
#how to change this url?
html = '''
<a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb">
  <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
</a>'''
HTML(html)
# Out:
# <a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
